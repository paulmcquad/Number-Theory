# %%
# Tables Mod n
# https://crypto.katestange.net/multiplication-tables-modulo-n/

n = 71
R = IntegerModRing(n)
U = IntegerModRing(euler_phi(n))
rows = [[i^r for r in U] for i in R]
matrix_plot(matrix(rows))
# Out:
# Graphics object consisting of 1 graphics primitive
